# %%
import numpy as np
import sys

# %% [markdown]
# ## With DualSimplexSolver

# %%
from functions.DualSimplexSolver import DualSimplexSolver
if __name__ == "__main__":
    try:
        example_obj_type = 'max'
        example_c = [-2, -3,-1]
        example_A = [
            [1, 4,2],
            [3, 2,0],
        ]
        example_relations = ['>=', '>=']
        example_b = [8,6]

        solver = DualSimplexSolver(example_obj_type, example_c, example_A, example_relations, example_b)
        solver.solve()
    except Exception as e:
        print(f"\nAn error occurred: {e}")
        import traceback
        traceback.print_exc()
# Out:
# --- Starting Dual Simplex Method ---
#
# --- Iteration 0 ---
#       BV        Z       x1       x2       x3       s1       s2      RHS
# ------------------------------------------------------------------------
#        Z    1.000    2.000    3.000    1.000    0.000    0.000    0.000
#       s1    0.000   -1.000   -4.000   -2.000    1.000    0.000   -8.000
#       s2    0.000   -3.000   -2.000   -0.000    0.000    1.000   -6.000
# ------------------------------------------------------------------------
#
# Step: Select Pivot Row (Leaving Variable)
#    RHS values (b): [-8. -6.]
#    Most negative RHS is -8.000 in Row 1 (Basic Var: s1).
#    Leaving Variable: s1 (Row 1)
#
# Step: Select Pivot Column (Entering Variable) using Ratio Test
#    Pivot Row (Row 1) coefficients (excluding Z, RHS): [-1. -4. -2.  1.  0.]
#    Objective Row coefficients (excluding Z, RHS): [2. 3. 1. 0. 0.]
#    Calculating ratios = ObjCoeff / abs(PivotRowCoeff) for PivotRowCoeff < 0:
#       Var x1 (Col 1): Coeff=-1.000, ObjCoeff=2.000, Ratio = 2.000 / 1.000 = 2.000
#       Var x2 (Col 2): Coeff=-4.000, ObjCoeff=3.000, Ratio = 3.000 / 4.000 = 0.750
#       Var x3 (Col 3): Coeff=-2.000, ObjCoeff=1.000, Ratio = 1.000 / 2.000 = 0.500
#    Minimum ratio is 0.500 for variable x3 (Column 3).
#    Entering Variable: x3 (Column 3)
#
# Step: Pivot Operation
#    Pivot Element: -2.000 at (Row 1, Col 3)
#    Normalizing Pivot Row 1 by dividing by -2.000
#    Eliminating other entries in Pivot Column 3:
#       Row 0 = Row 0 - (1.000) * (New Row 1)
#    Updating Basic Variables: x3 replaces s1 in the basis for Row 1.
#
# --- Iteration 1 ---
#       BV        Z       x1       x2       x3       s1       s2      RHS
# ------------------------------------------------------------------------
#        Z    1.000    1.500    1.000    0.000    0.500    0.000   -4.000
#       x3   -0.000    0.500    2.000    1.000   -0.500   -0.000    4.000
#       s2    0.000   -3.000   -2.000   -0.000    0.000    1.000   -6.000
# ------------------------------------------------------------------------
#
# Step: Select Pivot Row (Leaving Variable)
#    RHS values (b): [ 4. -6.]
#    Most negative RHS is -6.000 in Row 2 (Basic Var: s2).
#    Leaving Variable: s2 (Row 2)
#
# Step: Select Pivot Column (Entering Variable) using Ratio Test
#    Pivot Row (Row 2) coefficients (excluding Z, RHS): [-3. -2. -0.  0.  1.]
#    Objective Row coefficients (excluding Z, RHS): [1.5 1.  0.  0.5 0. ]
#    Calculating ratios = ObjCoeff / abs(PivotRowCoeff) for PivotRowCoeff < 0:
#       Var x1 (Col 1): Coeff=-3.000, ObjCoeff=1.500, Ratio = 1.500 / 3.000 = 0.500
#       Var x2 (Col 2): Coeff=-2.000, ObjCoeff=1.000, Ratio = 1.000 / 2.000 = 0.500
#    Tie detected for minimum ratio (0.500) among variables: ['x1', 'x2'].
#    Applying Bland's rule: Choosing variable with smallest index: x1.
#
# Step: Pivot Operation
#    Pivot Element: -3.000 at (Row 2, Col 1)
#    Normalizing Pivot Row 2 by dividing by -3.000
#    Eliminating other entries in Pivot Column 1:
#       Row 0 = Row 0 - (1.500) * (New Row 2)
#       Row 1 = Row 1 - (0.500) * (New Row 2)
#    Updating Basic Variables: x1 replaces s2 in the basis for Row 2.
#
# --- Iteration 2 ---
#       BV        Z       x1       x2       x3       s1       s2      RHS
# ------------------------------------------------------------------------
#        Z    1.000    0.000    0.000    0.000    0.500    0.500   -7.000
#       x3    0.000    0.000    1.667    1.000   -0.500    0.167    3.000
#       x1   -0.000    1.000    0.667    0.000   -0.000   -0.333    2.000
# ------------------------------------------------------------------------
#
# --- Optimal Solution Found ---
#    All RHS values are non-negative.
#
# --- Final Solution ---
#
# --- Iteration Final ---
#       BV        Z       x1       x2       x3       s1       s2      RHS
# ------------------------------------------------------------------------
#        Z    1.000    0.000    0.000    0.000    0.500    0.500   -7.000
#       x3    0.000    0.000    1.667    1.000   -0.500    0.167    3.000
#       x1   -0.000    1.000    0.667    0.000   -0.000   -0.333    2.000
# ------------------------------------------------------------------------
# Optimal Objective Value (Max Z): -7.000000
# Optimal Variable Values:
#    x1: 2.000000
#    x2: 0.000000
#    x3: 3.000000
# Slack/Surplus Variable Values:

# %% [markdown]
# ## Without DualSimplexSolver

# %%
from functions.get_user_input import get_user_input
from functions.solve_lp_via_dual import solve_lp_via_dual
from functions.solve_primal_directly import solve_primal_directly


use_example = True # Set to False to use user input

if use_example:
     print("--- Using Example Problem ---")
     example_obj_type = 'max'
     example_c = [-2, -3,-1]
     example_A = [
          [1, 4,2],
          [3, 2,0],
     ]
     example_relations = ['>=', '>=']
     example_b = [8,6]

     print(f"Objective: {example_obj_type} Z = {' + '.join([f'{co:.2f}*x{i+1}' for i, co in enumerate(example_c)])}")
     print("Constraints:")
     for i in range(len(example_A)):
          print(f"  {' + '.join([f'{aij:.2f}*x{j+1}' for j, aij in enumerate(example_A[i])])} {example_relations[i]} {example_b[i]:.2f}")
     print("------------------------\n")

     obj_type, c, A, relations, b = example_obj_type, example_c, example_A, example_relations, example_b
else:
     try:
          obj_type, c, A, relations, b = get_user_input()
          print("\n--- Problem Received ---")
          print(f"Objective: {obj_type} Z = {' + '.join([f'{co:.2f}*x{i+1}' for i, co in enumerate(c)])}")
          print("Constraints:")
          for i in range(len(A)):
               print(f"  {' + '.join([f'{aij:.2f}*x{j+1}' for j, aij in enumerate(A[i])])} {relations[i]} {b[i]:.2f}")
          print("------------------------\n")
     except Exception as e:
          print(f"\nAn error occurred during input: {e}")
          exit()

# Solve using the dual method
status, message, primal_sol, dual_sol, obj_val = solve_lp_via_dual(obj_type, c, A, relations, b)

print("\n" + "="*40)
print("          FINAL RESULT")
print("="*40)
print(f"Status: {status} ({message})")
if status == 0:
     print(f"Optimal Primal Objective Value: {obj_val:.6f}")
     print("Primal Variables (x*):")
     if primal_sol:
          for var, val in primal_sol.items():
               print(f"   {var}: {val:.6f}")
     print("Dual Variables (p*):")
     if dual_sol:
          # Map dual vars back to original constraints if possible (tricky due to splitting '=')
          # For simplicity, just print the p's as solved.
          for var, val in dual_sol.items():
               print(f"   {var}: {val:.6f}") # p_i corresponds to the i-th *standardized* constraint
print("="*40)

# Optional: Solve directly for comparison
print("\n--- Solving Primal Directly (for comparison) ---")
status_direct, msg_direct, psol_direct, _, obj_direct = solve_primal_directly(obj_type, c, A, relations, b)
if status_direct == 0:
     print(f"Direct Solve Optimal Value: {obj_direct:.6f}")
     print("Direct Solve Primal Variables:")
     for var, val in psol_direct.items():
          print(f"   {var}: {val:.6f}")
else:
     print(f"Direct Solve Failed: {msg_direct}")
print("="*40)
# Out:
# --- Using Example Problem ---
# Objective: max Z = -2.00*x1 + -3.00*x2 + -1.00*x3
# Constraints:
#   1.00*x1 + 4.00*x2 + 2.00*x3 >= 8.00
#   3.00*x1 + 2.00*x2 + 0.00*x3 >= 6.00
# ------------------------
#
# --- Step 1: Formulate the Dual Problem ---
#    Primal is Max. Converting to Min by negating objective coefficients.
#    Adjusting primal constraints to >= form for dual formulation:
#       Constraint 1: Keeping as >= ( [1. 4. 2.] >= 8.0 )
#       Constraint 2: Keeping as >= ( [3. 2. 0.] >= 6.0 )
#
#    Dual Problem Formulation:
#       Objective: Maximize p * [8.00, 6.00]
#       Subject to:
#          1.00*p1 + 3.00*p2 <= 2.00
#          4.00*p1 + 2.00*p2 <= 3.00
#          2.00*p1 + 0.00*p2 <= 1.00
#       p_i >= 0 for i=1..2
#
# --- Step 2: Solve the Dual Problem using SciPy linprog ---
#
#    Optimal Dual Solution Found:
#       Dual Variables (p*):
#          p1 = 0.500000
#          p2 = 0.500000
#       Optimal Dual Objective Value (Max p*b): 7.000000
#
# --- Step 3: Check Strong Duality ---
#    Strong duality implies the optimal primal objective value should be: -7.000000
#
# --- Step 4 & 5: Use Complementary Slackness to find Primal Variables ---
#    Calculating Dual Slacks (c'_j - p* A'_j):
#       Dual Slack for primal var x1: 0.000000
#       Dual Slack for primal var x2: 0.000000
#       Dual Slack for primal var x3: 0.000000
#
#    Applying Complementary Slackness Conditions:
#       From Dual Slackness (if c'_j - p* A'_j > 0, then x*_j = 0):
#          Dual Slack for x1 is 0.0000 approx 0 => x1* may be non-zero
#          Dual Slack for x2 is 0.0000 approx 0 => x2* may be non-zero
#          Dual Slack for x3 is 0.0000 approx 0 => x3* may be non-zero
#       From Primal Slackness (if p*_i > 0, then primal constraint i is binding):
#          p*1 = 0.5000 > 0 => Primal constraint 1 (standardized) is binding.
#          p*2 = 0.5000 > 0 => Primal constraint 2 (standardized) is binding.
#
#    Identifying system for active primal variables (['x1', 'x2', 'x3']):
#       Warning: Number of binding constraints (2) identified is less than the number of potentially non-zero primal variables (3).
#       Complementary slackness alone might not be sufficient, or there might be degeneracy/multiple solutions.
#       Attempting to solve using available binding constraints, but result might be unreliable.
#       System is underdetermined. Using least squares (minimum norm) solution.
#
#       Solved values for active primal variables:
#          x1* = 1.000000
#          x2* = 1.500000
#          x3* = 0.500000
#
# --- Step 6: Verify Primal Solution ---
#    Checking primal constraints:
#       Constraint 1: 8.0000 >= 8.0000 -> Satisfied
#       Constraint 2: 6.0000 >= 6.0000 -> Satisfied
#    Checking non-negativity (x >= 0):
#       All x_j >= 0: True
#
#    Calculated Primal Objective Value: -7.000000
#    Expected Primal Objective Value (from dual): -7.000000
#
# --- Primal Solution Found Successfully via Dual ---
#
# ========================================
#           FINAL RESULT
# ========================================
# Status: 0 (Optimal solution found via dual.)
# Optimal Primal Objective Value: -7.000000
# Primal Variables (x*):
#    x1: 1.000000
#    x2: 1.500000
#    x3: 0.500000
# Dual Variables (p*):
#    p1: 0.500000
#    p2: 0.500000
# ========================================
#
# --- Solving Primal Directly (for comparison) ---
# Direct Solve Optimal Value: -7.000000
# Direct Solve Primal Variables:
#    x1: 0.800000
#    x2: 1.800000
#    x3: 0.000000
# ========================================
